# %%
# !pip install flask
# Out:
# Requirement already satisfied: flask in c:\users\lakshmilokeswari\anaconda3\lib\site-packages (3.1.0)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\lakshmilokeswari\anaconda3\lib\site-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\lakshmilokeswari\anaconda3\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\lakshmilokeswari\anaconda3\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\lakshmilokeswari\anaconda3\lib\site-packages (from flask) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in c:\users\lakshmilokeswari\anaconda3\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: colorama in c:\users\lakshmilokeswari\anaconda3\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lakshmilokeswari\anaconda3\lib\site-packages (from Jinja2>=3.1.2->flask) (3.0.2)

# %%
from flask import Flask, request

app = Flask(__name__)

@app.route("/name")
def convert_to_upper():
    user_name = request.args.get("user")

    if not user_name:
        return "<h3 style='color:red'>Please provide a name in URL</h3>"

    upper_name = user_name.upper()

    return f"""
    <h2>Username Converter</h2>
    <p><b>Original Name:</b> {user_name}</p>
    <p><b>Upper Case Name:</b> {upper_name}</p>
    """

# %%
app.run(port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
